# %% [markdown]
# ### 1. What is the difference between the two models?
#
# Well, we can clearly see that both models have a tendency to predict bible verses, but the first model GPT-2 without any fine-tuning performed much worse. The prediction from GPT-2 were basically just random lines from the bible. The second model, the fine-tuned GPT-2 even if it didn't predict poetry, it at least had a more verse-like aesthetic and it didn't veer off as much towards random bible verses. So we can say that the fine-tuning process did improve the model's ability to predict poetry, even if it didn't make it perfect.
#
# ### 2. What happens if the prompt is a poem in English?
#
# Nothing that you wouldn't expect. The model will try to predict the next line of the poem, but since it was fine-tuned on a dataset of poetry in English, it will be able to predict the next line of the poem.
#
# ### 3. What happenes if the prompt is a poem in Romanian?
#
# Can you believe it? The model is predicting gibberish! This is because GPT-2 was trained on English text, so it doesn't understand Romanian. The tokenizer is just splitting the word into letters because it doesn't recognize the vocabulary. So it just predicting based on random input.
#
# ```txt
# De-aș avea și eu o floare
# Mândră, dulce, răpitoare,
# I am in the forest! I have seen you; see me now. O my mother--who
# Fiice dulce-a unui plai,
# Alyonahwisme mamum and roatia—no wonder there is no
# Ce se leagănă, se pierde,
# O king's son!" he exclaimed,— "Gentlemen of all nations are afraid to tell your
# Șoptind șoapte de amor;
# ```
#
# But it looks funny :P
#
# ### 4. What happens if the lyrics in the prompt are in Romanian and the training corpus is in English?
#
# This is what happens at the previous question. If we had a model trained on Romanian poetry we could get a better result.
#
# ### 5. How can we personalize a LLM to be generate more pastel verses that focus on the beauty of nature?
#
# To personalize a LLM to generate more pastel verses that focus on the beauty of nature, we can fine-tune the model on a dataset of poetry that has the desired style and content. For example, we can create a dataset of poems that are written in a pastel style and that focus on the beauty of nature. We can then use this dataset to fine-tune the model, which will help it learn to generate poetry in the desired style and with the desired content. Additionally, we can also experiment with different hyperparameters during the fine-tuning process, such as learning rate and batch size, to further improve the model's performance.
#
# Alos a higher temperature with a lower top-p ccoulld help make the poem more creative.
